# %% [markdown]
# # process the datasets for DINO
# 1. Recursively traverse a parent folder (which contains only subfolders).
# 2. Read each 4-channel .tif/.TIF (uint16) in the subfolders.
# 3. Compute how many 224×224 patches fit fully in the image, then place that grid centered within the image.
# 4. Skip any patch that contains 0 or 65535 (“NaNs”).
# 5. Perform per-patch min–max scaling (valid range to 0–2550–255).
# 6. Save each valid chip as a 4-channel .tif, with the file name format
# - OriginalFileName_rowStart_colStart.tif
#
# 7. Show a progress bar for:
#
# - The list of TIF images being processed, and
# - The row/column tiling for each image (nested progress bars).

# %%
import os
import glob
import numpy as np
import tifffile
from tqdm import tqdm
import re


def clean_filename(filename: str):
    """Remove any extra '.tif' or '.TIF' extensions from the filename."""
    return re.sub(r'(\.tif)+$', '', filename, flags=re.IGNORECASE)

    
def chip_and_save_tifs(
    input_folder: str,
    output_folder: str,
    chip_size: int = 224
):
    """
    Recursively traverse subfolders in `input_folder`, read 4-channel .tif/.TIF
    images (uint16), tile them into 224x224 patches in a grid that is
    centered in the image, drop patches with any 0 or 65535, min-max scale
    to [0, 255], and save them to `output_folder`. Includes tqdm progress bars.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Gather all subdirectories
    subdirs = [d for d in os.scandir(input_folder) if d.is_dir()]

    for subdir in subdirs:
        # Collect both .tif and .TIF files in this subdir
        tif_files = glob.glob(os.path.join(subdir.path, "*.tif")) \
                  + glob.glob(os.path.join(subdir.path, "*.TIF"))

        # If no TIFs found in this subdir, move on
        if not tif_files:
            continue

        # Create a sub-progress bar for TIF files in this subdir
        for tif_path in tqdm(tif_files, desc=f"Processing TIFs in {subdir.name}", unit="file"):
            raw_filename = os.path.basename(tif_path)
            filename = clean_filename(os.path.splitext(raw_filename)[0])  # Strip extra ".tif"


            # Read the 4-channel image with tifffile
            img = tifffile.imread(tif_path)
            # Expected shape: (height, width, channels) or (channels, height, width)

            if img.ndim != 3:
                print(f"Skipping {tif_path}: not a 3D array (found shape: {img.shape}).")
                continue

            # If channels are first, transpose to (H, W, C)
            # so we end up with shape: (height, width, 4)
            if img.shape[0] == 4 and (img.shape[1] != 4 and img.shape[2] != 4):
                img = np.transpose(img, (1, 2, 0))
            elif img.shape[-1] != 4:
                print(f"Skipping {tif_path}: not a 4-channel image.")
                continue

            # Ensure uint16
            if img.dtype != np.uint16:
                print(f"Warning: {tif_path} not in uint16. Found {img.dtype}, converting.")
                img = img.astype(np.uint16)

            height, width, channels = img.shape

            # How many full patches along each dimension?
            n_rows = height // chip_size
            n_cols = width // chip_size

            # If the image is too small for even one 224x224 patch, skip
            if n_rows == 0 or n_cols == 0:
                print(f"Skipping {tif_path}: image too small for {chip_size}x{chip_size} patches.")
                continue

            # Total covered area
            covered_height = n_rows * chip_size
            covered_width = n_cols * chip_size

            # Offsets to center the grid
            offset_row = (height - covered_height) // 2
            offset_col = (width - covered_width) // 2

            # Nested progress bars for row and column tiling
            for row_idx in range(n_rows):
                for col_idx in range(n_cols):
                    row_start = offset_row + row_idx * chip_size
                    col_start = offset_col + col_idx * chip_size

                    # Extract the chip
                    chip = img[row_start:row_start + chip_size,
                               col_start:col_start + chip_size, :]

                    # Skip if any pixel in the chip is 0 or 65535
                    if np.any(chip == 0) or np.any(chip == 65535):
                        continue

                    # Convert to float for min-max scaling
                    chip_float = chip.astype(np.float32)
                    valid_min = chip_float.min()
                    valid_max = chip_float.max()

                    # Avoid divide-by-zero if min == max
                    if valid_min == valid_max:
                        continue

                    # Scale to [0, 255]
                    chip_scaled = 255.0 * (chip_float - valid_min) / (valid_max - valid_min)
                    chip_scaled = chip_scaled.astype(np.uint8)

                    # Output name: originalfilename_row_col.tif
                    out_chip_name = f"{filename}_{row_start}_{col_start}.tif"
                    out_chip_path = os.path.join(output_folder, out_chip_name)

                    tifffile.imwrite(
                        out_chip_path,
                        chip_scaled,
                        dtype=chip_scaled.dtype,
                    )

    print("Chipping complete.")

# %%
# Example usage
input_dir = "../data/processed"  # contains only subfolders, each with .tif/.TIF
output_dir = "../data/chipped_224"

chip_and_save_tifs(
    input_folder=input_dir,
    output_folder=output_dir,
    chip_size=224
)
# Out:
# Processing TIFs in 3m_miningwaste_a: 100%|█████████████████████████████████████████| 764/764 [01:43<00:00,  7.41file/s]
# Processing TIFs in 3m_miningwaste_b: 100%|███████████████████████████████████████████| 24/24 [00:04<00:00,  5.32file/s]
# Processing TIFs in 3m_miningwaste_c: 100%|███████████████████████████████████████████| 98/98 [00:11<00:00,  8.74file/s]
# Processing TIFs in 3m_nitrogen: 100%|██████████████████████████████████████████████| 168/168 [00:49<00:00,  3.37file/s]
# Processing TIFs in 3m_olivegrove_cimadimelfimisto: 100%|███████████████████████████| 166/166 [00:42<00:00,  3.90file/s]
# Processing TIFs in 3m_olivegrove_francese: 100%|███████████████████████████████████| 224/224 [00:53<00:00,  4.18file/s]
# Processing TIFs in 3m_olivegrove_leccino: 100%|████████████████████████████████████| 210/210 [00:49<00:00,  4.22file/s]
# Processing TIFs in 3m_olivegrove_ulivigrandea: 100%|█████████████████████████████| 1144/1144 [05:22<00:00,  3.55file/s]
# Processing TIFs in 3m_olivegrove_ulivigrandeb: 100%|███████████████████████████████| 282/282 [01:14<00:00,  3.81file/s]
# Processing TIFs in 3m_portugal_vineyard_jpra: 100%|████████████████████████████████| 308/308 [00:24<00:00, 12.72file/s]
# Processing TIFs in 3m_portugal_vineyard_jprb: 100%|████████████████████████████████| 210/210 [00:22<00:00,  9.33file/s]
# Processing TIFs in 3m_portugal_vineyard_jprc: 100%|████████████████████████████████| 212/212 [00:21<00:00,  9.90file/s]
# Processing TIFs in 3m_portugal_vineyard_reynoldsa: 100%|███████████████████████████| 168/168 [00:29<00:00,  5.79file/s]
# Processing TIFs in 3m_portugal_vineyard_reynoldsb: 100%|███████████████████████████| 152/152 [00:27<00:00,  5.56file/s]
# Processing TIFs in 3m_portugal_vineyard_reynoldsc: 100%|███████████████████████████| 162/162 [00:30<00:00,  5.33file/s]
# Processing TIFs in 3m_uk_vineyard_east_july: 100%|█████████████████████████████████| 524/524 [02:06<00:00,  4.16file/s]
# Processing TIFs in 3m_uk_vineyard_east_june: 100%|███████████████████████████████| 1926/1926 [07:12<00:00,  4.45file/s]
# Processing TIFs in 3m_uk_vineyard_mid_july: 100%|████████████████████████████████| 1016/1016 [03:57<00:00,  4.28file/s]
# Processing TIFs in 3m_uk_vineyard_west_july: 100%|███████████████████████████████| 1270/1270 [04:56<00:00,  4.28file/s]
# Processing TIFs in 3m_uk_vineyard_west_sept: 100%|███████████████████████████████| 1270/1270 [04:58<00:00,  4.26file/s]
# Processing TIFs in altum_beechforest: 100%|████████████████████████████████████████████| 2/2 [00:02<00:00,  1.46s/file]
# Processing TIFs in altum_macroalgae: 100%|█████████████████████████████████████████████| 8/8 [00:14<00:00,  1.81s/file]
# Processing TIFs in p4m_cocao_b01_multi1: 100%|█████████████████████████████████████| 182/182 [00:19<00:00,  9.29file/s]
# Processing TIFs in p4m_cocao_b01_multi2: 100%|███████████████████████████████████████| 34/34 [00:03<00:00,  8.87file/s]
# Processing TIFs in p4m_cocao_b01_multi3: 100%|███████████████████████████████████████| 50/50 [00:05<00:00,  9.00file/s]
# Processing TIFs in p4m_cocao_b02_multi: 100%|██████████████████████████████████████| 180/180 [00:21<00:00,  8.51file/s]
# Processing TIFs in p4m_cocao_b02_multi1: 100%|███████████████████████████████████████| 40/40 [00:05<00:00,  7.10file/s]
# Processing TIFs in p4m_cocao_b02_multi2: 100%|███████████████████████████████████████| 44/44 [00:05<00:00,  7.75file/s]
# Processing TIFs in p4m_cocao_b03_multi: 100%|██████████████████████████████████████| 100/100 [00:11<00:00,  8.42file/s]
# Processing TIFs in p4m_cocao_b04_multi: 100%|██████████████████████████████████████| 134/134 [00:18<00:00,  7.24file/s]
# Processing TIFs in p4m_cocao_b05_multi: 100%|██████████████████████████████████████| 192/192 [00:26<00:00,  7.29file/s]
# Processing TIFs in p4m_cocao_b05_multi1: 100%|███████████████████████████████████████| 30/30 [00:03<00:00,  9.49file/s]
# Processing TIFs in p4m_cocao_b05_multi2: 100%|█████████████████████████████████████| 192/192 [00:20<00:00,  9.52file/s]
# Processing TIFs in p4m_cocao_b05_multi3: 100%|███████████████████████████████████████| 56/56 [00:05<00:00,  9.63file/s]
# Processing TIFs in p4m_cocao_b05_multi4: 100%|███████████████████████████████████████| 18/18 [00:01<00:00,  9.42file/s]
# Processing TIFs in p4m_cocao_b06_multi: 100%|██████████████████████████████████████| 182/182 [00:18<00:00,  9.59file/s]
# Processing TIFs in p4m_cocao_b06_multi2: 100%|███████████████████████████████████████| 68/68 [00:06<00:00, 10.03file/s]
# Processing TIFs in p4m_cocao_b06_multi3: 100%|███████████████████████████████████████| 70/70 [00:07<00:00,  9.81file/s]
# Processing TIFs in p4m_cocao_b07_multi: 100%|██████████████████████████████████████| 190/190 [00:19<00:00,  9.85file/s]
# Processing TIFs in p4m_cocao_b07_multi1: 100%|███████████████████████████████████████| 82/82 [00:08<00:00,  9.94file/s]
# Processing TIFs in p4m_cocao_b07_multi2: 100%|█████████████████████████████████████| 136/136 [00:13<00:00,  9.82file/s]
# Processing TIFs in p4m_cocao_b08_multi: 100%|██████████████████████████████████████| 178/178 [00:20<00:00,  8.85file/s]
# Processing TIFs in p4m_cocao_b08_multi1: 100%|███████████████████████████████████████| 50/50 [00:05<00:00,  9.67file/s]
# Processing TIFs in p4m_cocao_b08_multi2: 100%|███████████████████████████████████████| 16/16 [00:01<00:00,  9.00file/s]
# Processing TIFs in p4m_cocao_b09_multi: 100%|██████████████████████████████████████| 170/170 [00:18<00:00,  9.38file/s]
# Processing TIFs in p4m_cocao_b09_multi1: 100%|███████████████████████████████████████| 48/48 [00:04<00:00,  9.93file/s]
# Processing TIFs in p4m_cocao_b10_multi: 100%|██████████████████████████████████████| 104/104 [00:10<00:00,  9.80file/s]
# Processing TIFs in p4m_tropical_dry: 100%|█████████████████████████████████████████| 196/196 [00:19<00:00,  9.89file/s]
# Processing TIFs in p4m_tropical_rain: 100%|████████████████████████████████████████| 196/196 [00:19<00:00,  9.85file/s]
# Processing TIFs in rededge_blueberry: 100%|████████████████████████████████████████████| 2/2 [00:10<00:00,  5.31s/file]
# Processing TIFs in rededge_botrytis_a: 100%|█████████████████████████████████████| 2542/2542 [03:07<00:00, 13.54file/s]
# Processing TIFs in rededge_botrytis_b: 100%|█████████████████████████████████████| 1052/1052 [01:48<00:00,  9.65file/s]
# Processing TIFs in rededge_botrytis_c: 100%|█████████████████████████████████████| 1740/1740 [02:52<00:00, 10.06file/s]
# Processing TIFs in rededge_botrytis_d: 100%|█████████████████████████████████████| 1198/1198 [01:32<00:00, 12.92file/s]
# Processing TIFs in rededge_contamination_a: 100%|████████████████████████████████████| 32/32 [00:01<00:00, 18.97file/s]
# Processing TIFs in rededge_contamination_b: 100%|██████████████████████████████████| 246/246 [00:13<00:00, 17.68file/s]
# Processing TIFs in rededge_contamination_c: 100%|██████████████████████████████████| 400/400 [00:23<00:00, 16.96file/s]
# Processing TIFs in rededge_contamination_d: 100%|██████████████████████████████████| 400/400 [00:24<00:00, 16.17file/s]
# Processing TIFs in rededge_contamination_e: 100%|██████████████████████████████████| 178/178 [00:09<00:00, 19.07file/s]
# Processing TIFs in rededge_contamination_f: 100%|██████████████████████████████████| 254/254 [00:13<00:00, 18.17file/s]
# Processing TIFs in rededge_contamination_g: 100%|██████████████████████████████████| 344/344 [00:22<00:00, 15.41file/s]
# Processing TIFs in rededge_forestfuel: 100%|███████████████████████████████████████| 156/156 [02:35<00:00,  1.01file/s]
# Processing TIFs in rededge_potato_a: 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.81s/file]
# Processing TIFs in rededge_potato_b: 100%|█████████████████████████████████████████████| 2/2 [00:05<00:00,  2.54s/file]
# Processing TIFs in rededge_potato_c: 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.83s/file]
# Processing TIFs in rededge_potato_d: 100%|█████████████████████████████████████████████| 2/2 [00:02<00:00,  1.38s/file]
# Processing TIFs in rededge_potato_e: 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00,  3.19file/s]
# Processing TIFs in rededge_potato_f: 100%|█████████████████████████████████████████████| 2/2 [00:01<00:00,  1.92file/s]
# Processing TIFs in rededge_rivers_kk: 100%|████████████████████████████████████████████| 6/6 [00:02<00:00,  2.18file/s]
# Processing TIFs in rededge_rivers_lh: 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 23.16file/s]
# Processing TIFs in rededge_rivers_nw: 100%|████████████████████████████████████████████| 2/2 [00:00<00:00, 23.39file/s]
# Processing TIFs in sequioa_cherry_a: 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00, 21.61file/s]
# Processing TIFs in sequioa_cherry_b: 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00, 10.12file/s]
# Processing TIFs in sequioa_cherry_c: 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00, 17.41file/s]
# Processing TIFs in sequioa_cherry_d: 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00, 21.28file/s]
# Processing TIFs in sequioa_cherry_e: 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00, 20.48file/s]
# Processing TIFs in sequioa_nature_reserve: 100%|███████████████████████████████████████| 2/2 [01:08<00:00, 34.20s/file]
# Processing TIFs in sequoia_diurnal: 100%|██████████████████████████████████████████████| 2/2 [00:02<00:00,  1.05s/file]
# Processing TIFs in sequoia_localization: 100%|█████████████████████████████████████| 448/448 [00:07<00:00, 56.33file/s]
# Processing TIFs in sequoia_subtropical_a: 100%|████████████████████████████████████| 544/544 [00:14<00:00, 37.79file/s]
# Processing TIFs in sequoia_subtropical_b: 100%|████████████████████████████████████| 834/834 [00:20<00:00, 39.85file/s]
# Processing TIFs in sequoia_subtropical_c: 100%|████████████████████████████████████| 574/574 [00:12<00:00, 44.34file/s]
# Chipping complete.

# %%
import os
import glob
import numpy as np
import tifffile
from tqdm import tqdm
import re
import multiprocessing
import numpy as np
from scipy.signal import convolve2d


import numpy as np

def skip_chip(chip: np.ndarray,factor=0.3) -> bool:
    """
    Returns True if more than 30% of all band-pixels in this chip are 0 or 65535.
    
    chip.shape is assumed to be (height, width, 4).
    """
    # Create a boolean mask for pixels that are 0 or 65535 (in any band)
    bad_mask = (chip == 0) | (chip == 65535)
    
    # Count how many pixels meet this criterion
    bad_count = np.count_nonzero(bad_mask)
    
    # Total number of band-pixels = height * width * 4
    total_count = chip.size  # same as chip.shape[0] * chip.shape[1] * chip.shape[2]
    
    # Fraction of band-pixels that are 0 or 65535
    fraction_bad = bad_count / total_count
    
    # Skip if fraction_bad > 0.30
    return fraction_bad > factor


        
def clean_filename(filename: str):
    """Remove any extra '.tif' or '.TIF' extensions from the filename."""
    return re.sub(r'(\.tif)+$', '', filename, flags=re.IGNORECASE)

def process_folder(subdir, output_folder, chip_size=224):
    """Processes all .tif/.TIF images in a given subdirectory."""
    tif_files = glob.glob(os.path.join(subdir, "*.tif")) + glob.glob(os.path.join(subdir, "*.TIF"))

    if not tif_files:
        return

    for tif_path in tif_files:
        raw_filename = os.path.basename(tif_path)
        filename = clean_filename(os.path.splitext(raw_filename)[0])  # Strip extra ".tif"

        # Read the 4-channel image with tifffile
        img = tifffile.imread(tif_path)

        if img.ndim != 3:
            print(f"Skipping {tif_path}: not a 3D array (found shape: {img.shape}).")
            continue

        # Ensure correct channel order
        if img.shape[0] == 4 and img.shape[1] != 4 and img.shape[2] != 4:
            img = np.transpose(img, (1, 2, 0))  # Convert (4, H, W) → (H, W, 4)
        elif img.shape[-1] != 4:
            print(f"Skipping {tif_path}: not a 4-channel image.")
            continue

        # Ensure uint16
        if img.dtype != np.uint16:
            print(f"Warning: {tif_path} not in uint16. Found {img.dtype}, converting.")
            img = img.astype(np.uint16)

        height, width, channels = img.shape

        # Compute the number of tiles that fit
        n_rows = height // chip_size
        n_cols = width // chip_size

        if n_rows == 0 or n_cols == 0:
            print(f"Skipping {tif_path}: image too small for {chip_size}x{chip_size} patches.")
            continue

        # Compute center-aligned grid
        covered_height = n_rows * chip_size
        covered_width = n_cols * chip_size
        offset_row = (height - covered_height) // 2
        offset_col = (width - covered_width) // 2

        # Process tiles
        for row_idx in range(n_rows):
            for col_idx in range(n_cols):
                row_start = offset_row + row_idx * chip_size
                col_start = offset_col + col_idx * chip_size

                # Extract chip
                chip = img[row_start:row_start + chip_size, col_start:col_start + chip_size, :]

                # If EITHER a 3×3 block is all 0 OR a 3×3 block is all 65535, skip it.
                if skip_chip(chip):
                    continue  # skip this chip

                # Convert to float for min-max scaling
                chip_float = chip.astype(np.float32)
                valid_min = chip_float.min()
                valid_max = chip_float.max()

                # Avoid divide-by-zero if min == max
                if valid_min == valid_max:
                    continue

                # Scale to [0, 255]
                chip_scaled = 255.0 * (chip_float - valid_min) / (valid_max - valid_min)
                chip_scaled = chip_scaled.astype(np.uint8)

                # Clean up output filename
                out_chip_name = f"{filename}_{row_start}_{col_start}.tif"
                out_chip_path = os.path.join(output_folder, out_chip_name)

                tifffile.imwrite(
                    out_chip_path,
                    chip_scaled,
                    dtype=chip_scaled.dtype,
                )

import os
import glob
import numpy as np
import tifffile
from tqdm import tqdm
import re
from concurrent.futures import ThreadPoolExecutor, as_completed


def parallel_process_folders(input_folder: str, output_folder: str, max_threads=4, chip_size=224):
    """
    Uses ThreadPoolExecutor to process each folder in parallel.
    Each folder runs in its own thread.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Gather all subdirectories
    subdirs = [d.path for d in os.scandir(input_folder) if d.is_dir()]

    with ThreadPoolExecutor(max_threads) as executor:
        future_to_subdir = {executor.submit(process_folder, subdir, output_folder, chip_size): subdir for subdir in subdirs}

        # Progress bar for folder-level execution
        for future in tqdm(as_completed(future_to_subdir), total=len(future_to_subdir), desc="Processing folders"):
            subdir = future_to_subdir[future]
            try:
                future.result()  # Check for exceptions
            except Exception as e:
                print(f"Error processing {subdir}: {e}")

    print("Parallel chipping complete.")

# %%
# Example usage
# Example usage
input_dir = "../data/processed/"  # contains only subfolders, each with .tif/.TIF
output_dir = "../data/chipped_448/"
num_cores = min(multiprocessing.cpu_count(), 8)  # Limit to 8 cores max

parallel_process_folders(
    input_folder=input_dir,
    output_folder=output_dir,
    max_threads=num_cores,
    chip_size=448
)
# Out:
# Processing folders: 100%|██████████████████████████████████████████████████████████████| 82/82 [21:27<00:00, 15.71s/it]
# Parallel chipping complete.

# %%
# Example usage
# Example usage
input_dir = "../data/processed/"  # contains only subfolders, each with .tif/.TIF
output_dir = "../data/chipped_336/"
num_cores = min(multiprocessing.cpu_count(), 8)  # Limit to 8 cores max

parallel_process_folders(
    input_folder=input_dir,
    output_folder=output_dir,
    max_threads=num_cores,
    chip_size=336
)
# Out:
# Processing folders: 100%|██████████████████████████████████████████████████████████████| 82/82 [24:44<00:00, 18.10s/it]
# Parallel chipping complete.

# %%
# Example usage
# Example usage
input_dir = "../data/processed/"  # contains only subfolders, each with .tif/.TIF
output_dir = "../data/chipped_512/"
num_cores = min(multiprocessing.cpu_count(), 8)  # Limit to 8 cores max

parallel_process_folders(
    input_folder=input_dir,
    output_folder=output_dir,
    max_threads=num_cores,
    chip_size=512
)
# Out:
# Processing folders: 100%|██████████████████████████████████████████████████████████████| 82/82 [27:30<00:00, 20.13s/it]
# Parallel chipping complete.
